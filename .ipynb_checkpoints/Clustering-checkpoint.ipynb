# %%
import numpy as np
import tqdm
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import os
from collections import defaultdict
from scipy.spatial import distance
from sklearn.metrics import calinski_harabaz_score, silhouette_score
from sklearn.cluster import DBSCAN, KMeans, SpectralClustering
from scipy.spatial import distance

methods_dict = {'dbscan':DBSCAN,
               'KMeans':KMeans,
               'SpectralClustering':SpectralClustering}

params_dict = {'dbscan':np.linspace(0.1, 2.0, 30),
               'KMeans':np.arange(2, 10, 1),
               'SpectralClustering':np.arange(3, 12, 2)}

# %%
# paths to the databases containing the PCA and Isomap projections 
root_pca = './separate_datasets_data'
paths_pca = [os.path.join(root_pca,path) for path in os.listdir(root_pca)]
paths_mf = [] 
paths = paths_pca + paths_mf

# %%
ls -la separate_datasets_data
# Out:
# total 50144
# drwxrwxr-x  2 ibulygin ibulygin     4096 нояб.  5 02:22 ./
# drwxrwxr-x 11 ibulygin ibulygin     4096 нояб.  5 12:22 ../
# -rw-rw-r--  1 ibulygin ibulygin  8489572 нояб.  4 19:32 AGP_proj_f.csv
# -rw-rw-r--  1 ibulygin ibulygin  2185325 нояб.  5 02:16 AGP_proj_f_isomap_dim_9_err_0-0448.csv
# -rw-rw-r--  1 ibulygin ibulygin  2182533 нояб.  5 02:18 AGP_proj_f_lle_dim_9_err_-0-0.csv
# -rw-rw-r--  1 ibulygin ibulygin 12629534 нояб.  4 19:32 AGP_proj_g.csv
# -rw-rw-r--  1 ibulygin ibulygin  2185068 нояб.  5 02:20 AGP_proj_g_isomap_dim_9_err_0-0421.csv
# -rw-rw-r--  1 ibulygin ibulygin  2182304 нояб.  5 02:22 AGP_proj_g_lle_dim_9_err_-0-0.csv
# -rw-rw-r--  1 ibulygin ibulygin  3894644 нояб.  4 19:32 AGP_proj_o.csv
# -rw-rw-r--  1 ibulygin ibulygin  1458020 нояб.  5 02:12 AGP_proj_o_isomap_dim_6_err_0-0246.csv
# -rw-rw-r--  1 ibulygin ibulygin  1454138 нояб.  5 02:13 AGP_proj_o_lle_dim_6_err_0-0032.csv
# -rw-rw-r--  1 ibulygin ibulygin    24197 нояб.  4 19:32 ibd_proj_f.csv
# -rw-rw-r--  1 ibulygin ibulygin     8780 нояб.  5 02:22 ibd_proj_f_isomap_dim_4_err_0-0664.csv
# -rw-rw-r--  1 ibulygin ibulygin     8765 нояб.  5 02:22 ibd_proj_f_lle_dim_4_err_0-029.csv
# -rw-rw-r--  1 ibulygin ibulygin    26414 нояб.  4 19:32 ibd_proj_g.csv
# -rw-rw-r--  1 ibulygin ibulygin    10992 нояб.  5 02:22 ibd_proj_g_isomap_dim_5_err_0-0448.csv
# -rw-rw-r--  1 ibulygin ibulygin     8796 нояб.  5 02:22 ibd_proj_g_lle_dim_4_err_0-0145.csv
# -rw-rw-r--  1 ibulygin ibulygin    13224 нояб.  4 19:32 ibd_proj_o.csv
# -rw-rw-r--  1 ibulygin ibulygin     6621 нояб.  5 02:13 ibd_proj_o_isomap_dim_3_err_0-0555.csv
# -rw-rw-r--  1 ibulygin ibulygin     6585 нояб.  5 02:13 ibd_proj_o_lle_dim_3_err_0-0125.csv
# -rw-rw-r--  1 ibulygin ibulygin  3179899 нояб.  4 19:32 ptb_proj_f.csv
# -rw-rw-r--  1 ibulygin ibulygin   618410 нояб.  5 02:10 ptb_proj_f_isomap_dim_7_err_0-1656.csv
# -rw-rw-r--  1 ibulygin ibulygin   616416 нояб.  5 02:10 ptb_proj_f_lle_dim_7_err_0-0042.csv
# -rw-rw-r--  1 ibulygin ibulygin  4320861 нояб.  4 19:32 ptb_proj_g.csv
# -rw-rw-r--  1 ibulygin ibulygin   617834 нояб.  5 02:13 ptb_proj_g_isomap_dim_7_err_0-1059.csv
# -rw-rw-r--  1 ibulygin ibulygin   617728 нояб.  5 02:13 ptb_proj_g_lle_dim_7_err_0-0049.csv
# -rw-rw-r--  1 ibulygin ibulygin  1590404 нояб.  4 19:32 ptb_proj_o.csv
# -rw-rw-r--  1 ibulygin ibulygin   442131 нояб.  5 02:13 ptb_proj_o_isomap_dim_5_err_0-1362.csv
# -rw-rw-r--  1 ibulygin ibulygin   443060 нояб.  5 02:13 ptb_proj_o_lle_dim_5_err_0-0055.csv
# -rw-rw-r--  1 ibulygin ibulygin   452489 нояб.  4 19:32 t2d_proj_f.csv
# -rw-rw-r--  1 ibulygin ibulygin   159906 нояб.  5 02:13 t2d_proj_f_isomap_dim_6_err_0-0231.csv
# -rw-rw-r--  1 ibulygin ibulygin   159897 нояб.  5 02:13 t2d_proj_f_lle_dim_6_err_0-0184.csv
# -rw-rw-r--  1 ibulygin ibulygin   452544 нояб.  4 19:32 t2d_proj_g.csv
# -rw-rw-r--  1 ibulygin ibulygin   159937 нояб.  5 02:13 t2d_proj_g_isomap_dim_6_err_0-0196.csv
# -rw-rw-r--  1 ibulygin ibulygin   159229 нояб.  5 02:13 t2d_proj_g_lle_dim_6_err_0-0265.csv
# -rw-rw-r--  1 ibulygin ibulygin   293176 нояб.  4 19:32 t2d_proj_o.csv
# -rw-rw-r--  1 ibulygin ibulygin   106342 нояб.  5 02:22 t2d_proj_o_isomap_dim_4_err_0-0097.csv
# -rw-rw-r--  1 ibulygin ibulygin   106242 нояб.  5 02:22 t2d_proj_o_lle_dim_4_err_0-0073.csv

# %%
# Davies Bouldin Index
def DB_index(X, clusters_centers, labels):
    if -1 in labels:
        X = X[labels != -1]
        labels = labels[labels != -1]
    n_clusters = len(clusters_centers)
    d = np.array([distance.euclidean(X[i], clusters_centers[labels[i]]) for i in range(len(X))])
    mean_dist = np.zeros(n_clusters)
    for i in range(n_clusters):
        mean_dist[i] = d[labels == i].mean()
    return sum([max([(mean_dist[i] + mean_dist[j]) / distance.euclidean(clusters_centers[i], clusters_centers[j]) 
         for i in range(n_clusters) if i != j]) for j in range(n_clusters)]) / n_clusters

# %%
# Clusters centers
def cl_centers(X, pred, n_cl=None):
    if n_cl is None:
        n_cl = len(set(pred))
        if -1 in pred:
            n_cl -= 1
    centers = np.zeros((n_cl, X.shape[1]))
    for i in range(n_cl):
        centers[i] = X[pred == i].mean(0)
    return centers

# %%
# sample the data via binomial mask
def sample_data(data, fraction):
    mask = np.random.binomial(1, fraction, data.shape[0]).astype(bool)
    return data[mask]

# %%
def plot_pca_proj_clustering(clustering_results, suptitle=None):
    fig, axes = plt.subplots(nrows=4, ncols=3, figsize=(20,15))
    for i,dataset_name in enumerate(['ptb', 'AGP', 't2d', 'ibd']):
        for j,tax_name in enumerate(['o', 'f', 'g']):
            label = f'{dataset_name}_proj_{tax_name}'
            data = clustering_results[label]
            df = pd.DataFrame(data=data).T
            df.columns = ['Davies-Bouldin index', 'silhouette_score']
            df.sort_index(ascending=False, inplace=True)
            ax = axes[i,j]
            ax.set_xlabel('# estimated clusters')
            ax.set_title(label)
            df.plot.bar(ax=ax)
    
    plt.tight_layout()
    if suptitle is not None:
        fig.suptitle(suptitle, fontsize=16, color='blue')
    plt.show()

# %%
def clustering(paths, method_class, param_range):
    # performing clustering
    cluster_results = defaultdict(dict)
    for path in tqdm.tqdm_notebook(paths):
        dataset = np.genfromtxt(path, delimiter=';')
        label = path.split("/")[-1].split(".")[0]
        for p in param_range:
            method = method_class(p)
            pred = method.fit_predict(dataset)
            if max(pred) > 0:
                centers = cl_centers(dataset, pred)
                ind = DB_index(dataset, centers, pred)
                silh = silhouette_score(dataset, pred)
                n = len(np.unique(pred[pred != -1]))

            cluster_results[label][n] = [ind, silh]
    return cluster_results

# %% [markdown]
# # DBSCAN

# %%
# Performing DBScan clustering
dbscan_results = defaultdict(dict)
dbscan_output = defaultdict(dict)
for path in tqdm.tqdm_notebook(paths):
    dataset = np.genfromtxt(path, delimiter=';')
    label = path.split("/")[-1].split(".")[0]
    indexes = []
    for eps in np.linspace(0.1, 2.0, 30):
        d = {}
        dbscan = DBSCAN(eps)
        pred = dbscan.fit_predict(dataset)
        if max(pred) > 0:
            centers = cl_centers(dataset, pred)
            ind = DB_index(dataset, centers, pred)
            silh = silhouette_score(dataset, pred)
            n = len(np.unique(pred[pred != -1]))
            d['eps'] = eps
            d['dbindex'] = ind
            d['silhouette_score'] = silh
            d['classes'] = n
            d['Classified_samples_ratio'] = (pred != -1).sum() / len(pred)

            indexes.append(ind)
        else:
            indexes.append(-1)
            
        dbscan_results[label][n] = [ind, silh]
        dbscan_output[label][eps] = d
# Out:
# HBox(children=(IntProgress(value=0, max=12), HTML(value='')))

# %%
plot_pca_proj_clustering(dbscan_results)

# %% [markdown]
# # KMEANS

# %%
# performing K-Means Clustering
kmeans_results = defaultdict(dict)
kmeans_output = defaultdict(dict)
for path in tqdm.tqdm_notebook(paths):
    dataset = np.genfromtxt(path, delimiter=';')
    label = path.split("/")[-1].split(".")[0]
    indexes = []
    for n in np.arange(2, 10, 1):
        d = {}
        kmeans = KMeans(int(n))
        pred = kmeans.fit_predict(dataset)
        if max(pred) > 0:
            centers = cl_centers(dataset, pred)
            silh = silhouette_score(dataset, pred)
            ind = DB_index(dataset, centers, pred)
            n = len(np.unique(pred[pred != -1]))
                                    
            d['n'] = n
            d['dbindex'] = ind
            d['silhouette_score'] = silh
            d['classes'] = n
            d['Classified_samples_ratio'] = (pred != -1).sum() / len(pred)
            
            indexes.append(ind)
        else:
            indexes.append(-1)
        
        kmeans_results[label][n] = [ind, silh]
        kmeans_output[label][n] = d
# Out:
# HBox(children=(IntProgress(value=0, max=12), HTML(value='')))

# %%
plot_pca_proj_clustering(kmeans_results)

# %% [markdown]
# # Spectral Clustering

# %%
# performing Spectral Clustering
spectral_results = defaultdict(dict)
spectral_output = defaultdict(dict)
for path in tqdm.tqdm_notebook(paths):
    dataset = np.genfromtxt(path, delimiter=';')
    label = path.split("/")[-1].split(".")[0]
    indexes = []
    for n in np.arange(3, 12, 2):
        sp = SpectralClustering(int(n))
        d = {}
        pred = sp.fit_predict(dataset)
        if max(pred) > 0:
            centers = cl_centers(dataset, pred)
            ind = DB_index(dataset, centers, pred)
            silh = silhouette_score(dataset, pred)
            n = len(np.unique(pred[pred != -1]))
            d['n'] = eps
            d['dbindex'] = ind
            d['silhouette_score'] = silh
            d['classes'] = n
            d['Classified_samples_ratio'] = (pred != -1).sum() / len(pred)
            
            indexes.append(ind)
        else:
            indexes.append(-1)
            
        spectral_results[label][n] = [ind, silh]
        spectral_output[label][eps] = d
# Out:
# HBox(children=(IntProgress(value=0, max=12), HTML(value='')))

# %%
plot_pca_proj_clustering(spectral_results)

# %% [markdown]
# # Aggregation

# %%
methods_names = list(methods_dict.keys())
datasets_names = sorted(list(spectral_results.keys()))

def create_clustering_pivot_table(results_list, methods_names, datasets_names):
    all_results = dict(zip(methods_names, results_list))
    X_dbind =np.zeros((len(methods_names), len(datasets_names)))
    X_silh =np.zeros((len(methods_names), len(datasets_names)))

    for i,(method_name) in tqdm.tqdm_notebook(enumerate(methods_names)):
        for j,(dataset_name) in enumerate(datasets_names):
            r = all_results[method_name][dataset_name]
            n_dbind = sorted(r, key=lambda x: r[x][0])[0] # minimized
            n_silh = sorted(r, key=lambda x: r[x][1])[-1] # maximized

            X_dbind[i,j] = n_dbind
            X_silh[i,j] = n_silh
    X_dbind = pd.DataFrame(data = X_dbind, columns=datasets_names, index=methods_names)
    X_silh = pd.DataFrame(data = X_silh, columns=datasets_names, index=methods_names)
    return X_dbind, X_silh

# %%
X_dbind, X_silh = create_clustering_pivot_table([dbscan_results, kmeans_results, spectral_results], methods_names, datasets_names)
# Out:
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))

# %% [markdown]
# # For ISOMAP

# %%
paths_mf = [os.path.join(root_mf,path) for path in os.listdir(root_mf)]
isomap_cluster_results_list = []
for mf_method_name in ['isomap']:    
    for method_name in methods_names:
        method_class = methods_dict[method_name]
        param_range = params_dict[method_name]
        cluster_results = clustering(paths, method_class, param_range)
        plot_pca_proj_clustering(cluster_results, suptitle=method_name)
        isomap_cluster_results_list.append(cluster_results)
# Out:
# HBox(children=(IntProgress(value=0, max=12), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=12), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=12), HTML(value='')))

# %%
X_dbind_isomap, X_silh_isomap = create_clustering_pivot_table(isomap_cluster_results_list, methods_names, datasets_names)
# Out:
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))

# %% [markdown]
# # LLE

# %%
paths_mf = [os.path.join(root_mf,path) for path in os.listdir(root_mf)]
lle_cluster_results_list = []
for mf_method_name in ['lle']:    
    for method_name in methods_names:
        method_class = methods_dict[method_name]
        param_range = params_dict[method_name]
        cluster_results = clustering(paths, method_class, param_range)
        plot_pca_proj_clustering(cluster_results, suptitle=method_name)
        lle_cluster_results_list.append(cluster_results)
# Out:
# HBox(children=(IntProgress(value=0, max=12), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=12), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=12), HTML(value='')))

# %%
X_dbind_lle, X_silh_lle = create_clustering_pivot_table(lle_cluster_results_list, methods_names, datasets_names)
# Out:
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))

# %% [markdown]
# # Aggregated pivot tables: DBIND

# %%
X_dbind_lle.index = [i + '_lle' for i in X_dbind_lle.index]
X_dbind_isomap.index = [i + '_isomap' for i in X_dbind_isomap.index]

# %%
X_dbind_all = pd.concat([X_dbind, X_dbind_lle, X_dbind_isomap], axis = 0)
X_dbind_all
# Out:
#                            AGP_proj_f  AGP_proj_g  AGP_proj_o  ibd_proj_f  \
# dbscan                            2.0         2.0         3.0         2.0
# KMeans                            2.0         3.0         2.0         9.0
# SpectralClustering               11.0         3.0        11.0         9.0
# dbscan_lle                        2.0         2.0         3.0         2.0
# KMeans_lle                        2.0         3.0         2.0         9.0
# SpectralClustering_lle           11.0         3.0        11.0         9.0
# dbscan_isomap                     2.0         2.0         3.0         2.0
# KMeans_isomap                     2.0         3.0         2.0         8.0
# SpectralClustering_isomap        11.0         3.0        11.0         9.0
#
#                            ibd_proj_g  ibd_proj_o  ptb_proj_f  ptb_proj_g  \
# dbscan                            5.0         3.0        20.0        21.0
# KMeans                            9.0         6.0         2.0         2.0
# SpectralClustering                7.0         7.0        11.0         7.0
# dbscan_lle                        5.0         3.0        20.0        21.0
# KMeans_lle                        9.0         6.0         2.0         2.0
# SpectralClustering_lle            7.0         7.0        11.0         7.0
# dbscan_isomap                     5.0         3.0        20.0        21.0
# KMeans_isomap                     9.0         7.0         2.0         2.0
# SpectralClustering_isomap         7.0         7.0         3.0         7.0
#
#                            ptb_proj_o  t2d_proj_f  t2d_proj_g  t2d_proj_o
# dbscan                           23.0         5.0         4.0         4.0
# KMeans                            2.0         3.0         3.0         2.0
# SpectralClustering                3.0         3.0         3.0         3.0
# dbscan_lle                       23.0         5.0         4.0         4.0
# KMeans_lle                        2.0         3.0         3.0         2.0
# SpectralClustering_lle            3.0         3.0         3.0         3.0
# dbscan_isomap                    23.0         5.0         4.0         4.0
# KMeans_isomap                     2.0         3.0         3.0         2.0
# SpectralClustering_isomap         3.0         3.0         3.0         3.0

# %% [markdown]
# # Aggregated pivot tables: SILHOETTE

# %%
X_silh_lle.index = [i + '_lle' for i in X_silh_lle.index]
X_silh_isomap.index = [i + '_isomap' for i in X_silh_isomap.index]
X_silh_all = pd.concat([X_silh, X_silh_lle, X_silh_isomap], axis = 0)
X_silh_all
# Out:
#                            AGP_proj_f  AGP_proj_g  AGP_proj_o  ibd_proj_f  \
# dbscan                            2.0         2.0         3.0         2.0
# KMeans                            4.0         3.0         3.0         9.0
# SpectralClustering                3.0         3.0         5.0         7.0
# dbscan_lle                        2.0         2.0         3.0         2.0
# KMeans_lle                        4.0         3.0         3.0         9.0
# SpectralClustering_lle            3.0         3.0         5.0         7.0
# dbscan_isomap                     2.0         2.0         3.0         2.0
# KMeans_isomap                     4.0         3.0         3.0         6.0
# SpectralClustering_isomap         3.0         3.0         5.0         7.0
#
#                            ibd_proj_g  ibd_proj_o  ptb_proj_f  ptb_proj_g  \
# dbscan                            6.0         3.0         3.0         9.0
# KMeans                            5.0         3.0         2.0         7.0
# SpectralClustering                5.0         3.0        11.0         3.0
# dbscan_lle                        6.0         3.0         3.0         9.0
# KMeans_lle                        5.0         3.0         2.0         7.0
# SpectralClustering_lle            5.0         3.0        11.0         3.0
# dbscan_isomap                     6.0         3.0         3.0         9.0
# KMeans_isomap                     5.0         4.0         2.0         7.0
# SpectralClustering_isomap         5.0         3.0        11.0         3.0
#
#                            ptb_proj_o  t2d_proj_f  t2d_proj_g  t2d_proj_o
# dbscan                            2.0         5.0         4.0         4.0
# KMeans                            8.0         3.0         3.0         2.0
# SpectralClustering                3.0         3.0         3.0         5.0
# dbscan_lle                        2.0         5.0         4.0         4.0
# KMeans_lle                        8.0         3.0         3.0         2.0
# SpectralClustering_lle            3.0         3.0         3.0         5.0
# dbscan_isomap                     2.0         5.0         4.0         4.0
# KMeans_isomap                     3.0         3.0         3.0         2.0
# SpectralClustering_isomap         3.0         3.0         3.0         5.0

# %% [markdown]
# # Visualisation

# %%
from sklearn.manifold import TSNE

for path in tqdm.tqdm_notebook(paths):
    dataset = np.genfromtxt(path, delimiter=';')
    label = path.split("/")[-1].split(".")[0]
    
    tsne2 = TSNE(2)
    tsne3 = TSNE(3)
